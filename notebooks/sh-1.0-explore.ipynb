# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %%
df_original = pd.read_csv('../data/raw/goodreads.csv')

# %%
df_original.head()
# Out:
#    Unnamed: 0                                       Book  \
# 0           0  The Restaurant at the End of the Universe
# 1           1                       The Name of the Rose
# 2           2                  The Clan of the Cave Bear
# 3           3                                Firestarter
# 4           4                                     Cosmos
#
#                                  Series Release number         Author  \
# 0  The Hitchhiker's Guide to the Galaxy              2  Douglas Adams
# 1                                   NaN            NaN    Umberto Eco
# 2                      Earth's Children              1   Jean M. Auel
# 3                                   NaN            NaN   Stephen King
# 4                                   NaN            NaN     Carl Sagan
#
#                                          Description  Num Pages  \
# 0  Facing annihilation at the hands of the warlik...      250.0
# 1  The year is 1327. Benedictines in a wealthy It...      536.0
# 2  This novel of awesome beauty and power is a mo...      512.0
# 3  The Department of Scientific Intelligence (aka...      564.0
# 4  The story of fifteen billion years of cosmic e...      384.0
#
#                   Format                                             Genres  \
# 0              Paperback  ['Science Fiction', 'Fiction', 'Humor', 'Fanta...
# 1              Paperback  ['Fiction', 'Historical Fiction', 'Mystery', '...
# 2              Paperback  ['Historical Fiction', 'Fiction', 'Fantasy', '...
# 3  Mass Market Paperback  ['Horror', 'Fiction', 'Thriller', 'Science Fic...
# 4  Mass Market Paperback  ['Science', 'Nonfiction', 'Physics', 'Astronom...
#
#      Publication Date Rating  Number of voters
# 0    October 12, 1980   4.21            283375
# 1     January 1, 1980   4.14            360732
# 2     January 1, 1980   4.09            264630
# 3  September 29, 1980   3.91            226270
# 4     January 1, 1980   4.39            144686

# %%
df_original.shape
# Out:
# (4400, 12)

# %%
df_original.describe()
# Out:
#         Unnamed: 0    Num Pages  Number of voters
# count  4400.000000  4366.000000      4.400000e+03
# mean   2199.500000   373.795007      1.422139e+05
# std    1270.314922   175.878588      3.917586e+05
# min       0.000000     2.000000      4.000000e+00
# 25%    1099.750000   278.000000      1.265300e+04
# 50%    2199.500000   352.000000      4.160300e+04
# 75%    3299.250000   440.000000      1.187932e+05
# max    4399.000000  1859.000000      9.848880e+06

# %%
print(df_original.isnull().sum()) #check for nulls, drop if nessassary
# Out:
# Unnamed: 0             0
# Book                   0
# Series              2171
# Release number      2185
# Author                 0
# Description            3
# Num Pages             34
# Format                 1
# Genres                 0
# Publication Date       1
# Rating                 0
# Number of voters       0
# dtype: int64

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4400 entries, 0 to 4399
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        4400 non-null   int64
#  1   Book              4400 non-null   object
#  2   Series            2229 non-null   object
#  3   Release number    2215 non-null   object
#  4   Author            4400 non-null   object
#  5   Description       4397 non-null   object
#  6   Num Pages         4366 non-null   float64
#  7   Format            4399 non-null   object
#  8   Genres            4400 non-null   object
#  9   Publication Date  4399 non-null   object
#  10  Rating            4400 non-null   object
#  11  Number of voters  4400 non-null   int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 412.6+ KB

# %%
df_original['Rating'] = pd.to_numeric(df_original['Rating'], errors='coerce')
df_original['Release number'] = pd.to_numeric(df_original['Release number'], errors='coerce')
df_original['Format'] = df_original['Format'].dropna()
df_original.head(10)
# Out:
#    Unnamed: 0                                       Book  \
# 0           0  The Restaurant at the End of the Universe
# 1           1                       The Name of the Rose
# 2           2                  The Clan of the Cave Bear
# 3           3                                Firestarter
# 4           4                                     Cosmos
# 5           5                        The Bourne Identity
# 6           6                    A Confederacy of Dunces
# 7           7                                      Congo
# 8           8                        One Corpse Too Many
# 9           9                 The Indian in the Cupboard
#
#                                  Series  Release number              Author  \
# 0  The Hitchhiker's Guide to the Galaxy             2.0       Douglas Adams
# 1                                   NaN             NaN         Umberto Eco
# 2                      Earth's Children             1.0        Jean M. Auel
# 3                                   NaN             NaN        Stephen King
# 4                                   NaN             NaN          Carl Sagan
# 5                          Jason Bourne             1.0       Robert Ludlum
# 6                                   NaN             NaN  John Kennedy Toole
# 7                                   NaN             NaN    Michael Crichton
# 8         Chronicles of Brother Cadfael             2.0        Ellis Peters
# 9            The Indian in the Cupboard             1.0    Lynne Reid Banks
#
#                                          Description  Num Pages  \
# 0  Facing annihilation at the hands of the warlik...      250.0
# 1  The year is 1327. Benedictines in a wealthy It...      536.0
# 2  This novel of awesome beauty and power is a mo...      512.0
# 3  The Department of Scientific Intelligence (aka...      564.0
# 4  The story of fifteen billion years of cosmic e...      384.0
# 5  Who is Jason Bourne? Is he an assassin, a terr...      566.0
# 6  Here is Ignatius Reilly: slob extraordinary, a...      394.0
# 7  Deep in the African rain forest, near the lege...      480.0
# 8  In the summer of 1138, war between King Stephe...      214.0
# 9  At first, Omri is unimpressed with the plastic...      192.0
#
#                   Format                                             Genres  \
# 0              Paperback  ['Science Fiction', 'Fiction', 'Humor', 'Fanta...
# 1              Paperback  ['Fiction', 'Historical Fiction', 'Mystery', '...
# 2              Paperback  ['Historical Fiction', 'Fiction', 'Fantasy', '...
# 3  Mass Market Paperback  ['Horror', 'Fiction', 'Thriller', 'Science Fic...
# 4  Mass Market Paperback  ['Science', 'Nonfiction', 'Physics', 'Astronom...
# 5              Paperback  ['Fiction', 'Thriller', 'Mystery', 'Suspense',...
# 6              Paperback  ['Fiction', 'Humor', 'Literature', 'Comedy', '...
# 7  Mass Market Paperback  ['Fiction', 'Science Fiction', 'Thriller', 'Ad...
# 8  Mass Market Paperback  ['Mystery', 'Historical Fiction', 'Fiction', '...
# 9              Paperback  ['Fantasy', 'Childrens', 'Fiction', 'Young Adu...
#
#      Publication Date  Rating  Number of voters
# 0    October 12, 1980    4.21            283375
# 1     January 1, 1980    4.14            360732
# 2     January 1, 1980    4.09            264630
# 3  September 29, 1980    3.91            226270
# 4     January 1, 1980    4.39            144686
# 5    February 4, 1980    4.05            431083
# 6         May 1, 1980    3.89            272471
# 7     January 1, 1980    3.62            170347
# 8        June 1, 1979    4.08             16138
# 9     January 1, 1980    3.93            105145

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4400 entries, 0 to 4399
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        4400 non-null   int64
#  1   Book              4400 non-null   object
#  2   Series            2229 non-null   object
#  3   Release number    2126 non-null   float64
#  4   Author            4400 non-null   object
#  5   Description       4397 non-null   object
#  6   Num Pages         4366 non-null   float64
#  7   Format            4399 non-null   object
#  8   Genres            4400 non-null   object
#  9   Publication Date  4399 non-null   object
#  10  Rating            4333 non-null   float64
#  11  Number of voters  4400 non-null   int64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 412.6+ KB

# %%
df_original.describe()
# Out:
#         Unnamed: 0  Release number    Num Pages       Rating  Number of voters
# count  4400.000000     2126.000000  4366.000000  4333.000000      4.400000e+03
# mean   2199.500000        3.428833   373.795007     4.020113      1.422139e+05
# std    1270.314922        4.067310   175.878588     0.243732      3.917586e+05
# min       0.000000        0.000000     2.000000     2.970000      4.000000e+00
# 25%    1099.750000        1.000000   278.000000     3.860000      1.265300e+04
# 50%    2199.500000        2.000000   352.000000     4.030000      4.160300e+04
# 75%    3299.250000        4.000000   440.000000     4.180000      1.187932e+05
# max    4399.000000       47.000000  1859.000000     4.810000      9.848880e+06

# %%
df_original = df_original.drop(columns=['Unnamed: 0'])
df_original.head()
# Out:
#                                         Book  \
# 0  The Restaurant at the End of the Universe
# 1                       The Name of the Rose
# 2                  The Clan of the Cave Bear
# 3                                Firestarter
# 4                                     Cosmos
#
#                                  Series  Release number         Author  \
# 0  The Hitchhiker's Guide to the Galaxy             2.0  Douglas Adams
# 1                                   NaN             NaN    Umberto Eco
# 2                      Earth's Children             1.0   Jean M. Auel
# 3                                   NaN             NaN   Stephen King
# 4                                   NaN             NaN     Carl Sagan
#
#                                          Description  Num Pages  \
# 0  Facing annihilation at the hands of the warlik...      250.0
# 1  The year is 1327. Benedictines in a wealthy It...      536.0
# 2  This novel of awesome beauty and power is a mo...      512.0
# 3  The Department of Scientific Intelligence (aka...      564.0
# 4  The story of fifteen billion years of cosmic e...      384.0
#
#                   Format                                             Genres  \
# 0              Paperback  ['Science Fiction', 'Fiction', 'Humor', 'Fanta...
# 1              Paperback  ['Fiction', 'Historical Fiction', 'Mystery', '...
# 2              Paperback  ['Historical Fiction', 'Fiction', 'Fantasy', '...
# 3  Mass Market Paperback  ['Horror', 'Fiction', 'Thriller', 'Science Fic...
# 4  Mass Market Paperback  ['Science', 'Nonfiction', 'Physics', 'Astronom...
#
#      Publication Date  Rating  Number of voters
# 0    October 12, 1980    4.21            283375
# 1     January 1, 1980    4.14            360732
# 2     January 1, 1980    4.09            264630
# 3  September 29, 1980    3.91            226270
# 4     January 1, 1980    4.39            144686

# %%
df_original.head()
# Out:
#                                         Book  \
# 0  The Restaurant at the End of the Universe
# 1                       The Name of the Rose
# 2                  The Clan of the Cave Bear
# 3                                Firestarter
# 4                                     Cosmos
#
#                                  Series  Release number         Author  \
# 0  The Hitchhiker's Guide to the Galaxy             2.0  Douglas Adams
# 1                                   NaN             NaN    Umberto Eco
# 2                      Earth's Children             1.0   Jean M. Auel
# 3                                   NaN             NaN   Stephen King
# 4                                   NaN             NaN     Carl Sagan
#
#                                          Description  Num Pages  \
# 0  Facing annihilation at the hands of the warlik...      250.0
# 1  The year is 1327. Benedictines in a wealthy It...      536.0
# 2  This novel of awesome beauty and power is a mo...      512.0
# 3  The Department of Scientific Intelligence (aka...      564.0
# 4  The story of fifteen billion years of cosmic e...      384.0
#
#                   Format                                             Genres  \
# 0              Paperback  ['Science Fiction', 'Fiction', 'Humor', 'Fanta...
# 1              Paperback  ['Fiction', 'Historical Fiction', 'Mystery', '...
# 2              Paperback  ['Historical Fiction', 'Fiction', 'Fantasy', '...
# 3  Mass Market Paperback  ['Horror', 'Fiction', 'Thriller', 'Science Fic...
# 4  Mass Market Paperback  ['Science', 'Nonfiction', 'Physics', 'Astronom...
#
#      Publication Date  Rating  Number of voters
# 0    October 12, 1980    4.21            283375
# 1     January 1, 1980    4.14            360732
# 2     January 1, 1980    4.09            264630
# 3  September 29, 1980    3.91            226270
# 4     January 1, 1980    4.39            144686

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4400 entries, 0 to 4399
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Book              4400 non-null   object
#  1   Series            2229 non-null   object
#  2   Release number    2126 non-null   float64
#  3   Author            4400 non-null   object
#  4   Description       4397 non-null   object
#  5   Num Pages         4366 non-null   float64
#  6   Format            4399 non-null   object
#  7   Genres            4400 non-null   object
#  8   Publication Date  4399 non-null   object
#  9   Rating            4333 non-null   float64
#  10  Number of voters  4400 non-null   int64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 378.3+ KB

# %%
df_original['Publication Date'] = pd.to_datetime(df_original['Publication Date'], errors='coerce')
df_original.info()
df_original.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4400 entries, 0 to 4399
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Book              4400 non-null   object
#  1   Series            2229 non-null   object
#  2   Release number    2126 non-null   float64
#  3   Author            4400 non-null   object
#  4   Description       4397 non-null   object
#  5   Num Pages         4366 non-null   float64
#  6   Format            4400 non-null   object
#  7   Genres            4400 non-null   object
#  8   Publication Date  4384 non-null   datetime64[ns]
#  9   Rating            4333 non-null   float64
#  10  Number of voters  4400 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 378.3+ KB
#                                         Book  \
# 0  The Restaurant at the End of the Universe
# 1                       The Name of the Rose
# 2                  The Clan of the Cave Bear
# 3                                Firestarter
# 4                                     Cosmos
#
#                                  Series  Release number         Author  \
# 0  The Hitchhiker's Guide to the Galaxy             2.0  Douglas Adams
# 1                                   NaN             NaN    Umberto Eco
# 2                      Earth's Children             1.0   Jean M. Auel
# 3                                   NaN             NaN   Stephen King
# 4                                   NaN             NaN     Carl Sagan
#
#                                          Description  Num Pages  \
# 0  Facing annihilation at the hands of the warlik...      250.0
# 1  The year is 1327. Benedictines in a wealthy It...      536.0
# 2  This novel of awesome beauty and power is a mo...      512.0
# 3  The Department of Scientific Intelligence (aka...      564.0
# 4  The story of fifteen billion years of cosmic e...      384.0
#
#                 Format                                             Genres  \
# 0            Paperback  ['Science Fiction', 'Fiction', 'Humor', 'Fanta...
# 1            Paperback  ['Fiction', 'Historical Fiction', 'Mystery', '...
# 2            Paperback  ['Historical Fiction', 'Fiction', 'Fantasy', '...
# 3  Massmarketpaperback  ['Horror', 'Fiction', 'Thriller', 'Science Fic...
# 4  Massmarketpaperback  ['Science', 'Nonfiction', 'Physics', 'Astronom...
#
#   Publication Date  Rating  Number of voters
# 0       1980-10-12    4.21            283375
# 1       1980-01-01    4.14            360732
# 2       1980-01-01    4.09            264630
# 3       1980-09-29    3.91            226270
# 4       1980-01-01    4.39            144686

# %%
import nltk
from nltk.tokenize import word_tokenize
format_counts = df_original['Format'].value_counts()
print(format_counts)

# Function to clean the format string
def clean_format(format_string):
    # Tokenize the format string into words
    if type(format_string) == float:
        return ''
    tokens = word_tokenize(format_string.title())
    
    # Remove unwanted characters and spaces
    #cleaned_tokens = [token for token in tokens if token not in ['[', ']', "'", "''", "``", " "]]
    
    # Join the cleaned tokens back into a string
    cleaned_format = ''.join(token for token in tokens if token.isalnum())
    clean_format = cleaned_format.strip()
    
    return clean_format

# Apply the clean_format function to the 'Format' column
df_original['Format'] = df_original['Format'].apply(clean_format)
# Out:
# Format
# Paperback              1824
# Hardcover              1367
# MassMarketPaperback     717
# KindleEdition           265
# Ebook                   129
# Nook                     14
# Pages                    13
# BoardBook                12
#                          12
# AudioCd                  11
# LibraryBinding            9
# AudioCassette             5
# TradePaperback            5
# Cassette                  4
# Cd                        3
# MarketPaperback           2
# UnknownBinding            2
# Audiobook                 2
# Broschiert                1
# SlipcasedHardcover        1
# Print                     1
# Paper                     1
# Name: count, dtype: int64

# %%
df_original['Format'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4400 entries, 0 to 4399
# Series name: Format
# Non-Null Count  Dtype
# --------------  -----
# 4400 non-null   object
# dtypes: object(1)
# memory usage: 34.5+ KB

# %%
def to_list(format_string):
    # Tokenize the format string into words
    if type(format_string) != str:
        return format_string
    
    lst = []
    genre = ''
    for letter in format_string:
        
        if letter == ',':
            lst.append(genre)
            genre = ''
        elif letter.isalnum() == True:
            genre += letter
        elif letter == ' ':
            genre += letter
        elif letter == ']':
            break
    output = []    
    for i in lst:
        output.append(i.strip())
    return output

df_original['Genres'] = df_original['Genres'].apply(to_list)

# %%
df_original['Genres'].head()
# Out:
# 0    [Science Fiction, Fiction, Humor, Fantasy, Com...
# 1    [Fiction, Historical Fiction, Mystery, Classic...
# 2    [Historical Fiction, Fiction, Fantasy, Histori...
# 3    [Horror, Fiction, Thriller, Science Fiction, F...
# 4    [Science, Nonfiction, Physics, Astronomy, Hist...
# Name: Genres, dtype: object
